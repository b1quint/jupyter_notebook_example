# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.random.rand(100)
y = np.random.rand(100)

fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(x, y, color='C0', marker='.')

fig.tight_layout()

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
